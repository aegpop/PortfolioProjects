# %%
import pandas as pd

# %%
df = pd.read_csv('supply.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
duplicated = df.duplicated().any()

if duplicated:
    print("Duplicated values found")
else:
    print("No duplicated values found")
# Out:
# No duplicated values found

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.tail()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 95        7386.363944               Unknown            15          14
# 96        7698.424766            Non-binary            67           2
# 97        4370.916580                  Male            46          19
# 98        8525.952560                Female            53           1
# 99        9185.185829               Unknown            55           8
#
#     Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(15,10))
plt.show()

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  Shipping times Shipping carriers  Shipping costs  \
# ...

# %%
df.drop(columns=['Availability', 'Revenue generated', 'Lead times', 'Shipping times', 'Defect rates', 'Costs'], inplace=True)

# %%
df.head()
# Out:
#   Product type   SKU      Price  Number of products sold  \
# 0     haircare  SKU0  69.808006                      802
# 1     skincare  SKU1  14.843523                      736
# 2     haircare  SKU2  11.319683                        8
# 3     skincare  SKU3  61.163343                       83
# 4     skincare  SKU4   4.805496                      871
#
#   Customer demographics  Stock levels  Order quantities Shipping carriers  \
# 0            Non-binary            58                96         Carrier B
# 1                Female            53                37         Carrier A
# 2               Unknown             1                88         Carrier B
# 3            Non-binary            23                59         Carrier C
# 4            Non-binary             5                56         Carrier A
#
#    Shipping costs Supplier name Location  Lead time  Production volumes  \
# 0        2.956572    Supplier 3   Mumbai         29                 215
# ...

# %%
df['Revenue'] = df['Price'] * df['Number of products sold']

# %%
df.head()
# Out:
#   Product type   SKU      Price  Number of products sold  \
# 0     haircare  SKU0  69.808006                      802
# 1     skincare  SKU1  14.843523                      736
# 2     haircare  SKU2  11.319683                        8
# 3     skincare  SKU3  61.163343                       83
# 4     skincare  SKU4   4.805496                      871
#
#   Customer demographics  Stock levels  Order quantities Shipping carriers  \
# 0            Non-binary            58                96         Carrier B
# 1                Female            53                37         Carrier A
# 2               Unknown             1                88         Carrier B
# 3            Non-binary            23                59         Carrier C
# 4            Non-binary             5                56         Carrier A
#
#    Shipping costs Supplier name Location  Lead time  Production volumes  \
# 0        2.956572    Supplier 3   Mumbai         29                 215
# ...

# %%
df['Customer demographics'].unique()
# Out:
# array(['Non-binary', 'Female', 'Unknown', 'Male'], dtype=object)

# %%
df['Customer demographics'] = df['Customer demographics'].replace({'Non-binary': 'Other', 'Unknown': 'Other'})

# %%
df.describe()
# Out:
#             Price  Number of products sold  Stock levels  Order quantities  \
# count  100.000000               100.000000    100.000000        100.000000
# mean    49.462461               460.990000     47.770000         49.220000
# std     31.168193               303.780074     31.369372         26.784429
# min      1.699976                 8.000000      0.000000          1.000000
# 25%     19.597823               184.250000     16.750000         26.000000
# 50%     51.239831               392.500000     47.500000         52.000000
# 75%     77.198228               704.250000     73.000000         71.250000
# max     99.171329               996.000000    100.000000         96.000000
#
#        Shipping costs   Lead time  Production volumes  \
# count      100.000000  100.000000          100.000000
# mean         5.548149   17.080000          567.840000
# std          2.651376    8.846251          263.046861
# min          1.013487    1.000000          104.000000
# ...

# %%
columns_to_plot = ['Price', 'Number of products sold', 'Stock levels', 
                   'Order quantities', 'Shipping costs', 'Lead time', 
                   'Production volumes', 'Manufacturing lead time', 
                   'Manufacturing costs']

# Creating the box plot
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
df[columns_to_plot].boxplot()
plt.title('Box Plot of Columns (excluding Revenue)')
plt.ylabel('Values')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
plt.grid(False)  # Optionally remove grid lines
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual DataFrame)
# Assuming your DataFrame is named df
# Replace this with your actual DataFrame
# df = ...

# Creating the box plot for 'Revenue'
plt.figure(figsize=(6, 4))  # Adjust the figure size if needed
df['Revenue'].plot(kind='box')
plt.title('Box Plot of Revenue')
plt.ylabel('Revenue')
plt.grid(False)  # Optionally remove grid lines
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual DataFrame)
# Assuming your DataFrame is named df
# Replace this with your actual DataFrame
# df = ...

# Define the revenue bins with a range of $10,000
revenue_bins = range(0, int(df['Revenue'].max()) + 10000, 10000)

# Group by 'Revenue Range' and sum the revenue in each bin
revenue_per_range = df.groupby(pd.cut(df['Revenue'], bins=revenue_bins, right=False))['Revenue'].sum()

# Calculate the total revenue
total_revenue = df['Revenue'].sum()

# Plot the bar chart
plt.figure(figsize=(10, 6))
revenue_per_range.plot(kind='bar', color='skyblue', label='Revenue per Range')
plt.axhline(y=total_revenue, color='red', linestyle='--', label='Total Revenue')
plt.xlabel('Revenue Range')
plt.ylabel('Revenue')
plt.title('Revenue Comparison by Range')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['Product cost'] = df['Manufacturing costs'] + df['Shipping costs']
df['Total lead time'] = df['Lead time'] + df['Manufacturing lead time']

# %%
df.tail()
# Out:
#    Product type    SKU      Price  Number of products sold  \
# 95     haircare  SKU95  77.903927                      672
# 96    cosmetics  SKU96  24.423131                      324
# 97     haircare  SKU97   3.526111                       62
# 98     skincare  SKU98  19.754605                      913
# 99     haircare  SKU99  68.517833                      627
#
#    Customer demographics  Stock levels  Order quantities Shipping carriers  \
# 95                 Other            15                26         Carrier B
# 96                 Other            67                32         Carrier C
# 97                  Male            46                 4         Carrier A
# 98                Female            53                27         Carrier B
# 99                 Other            55                59         Carrier B
#
#     Shipping costs Supplier name Location  Lead time  Production volumes  \
# 95        8.630339    Supplier 4   Mumbai         18                 450
# ...

# %%
truncate = ['Price', 'Shipping costs','Manufacturing costs', 'Revenue', 'Product cost']
df[truncate] = df[truncate].round(2)

# %%
df.head()
# Out:
#   Product type   SKU  Price  Number of products sold Customer demographics  \
# 0     haircare  SKU0  69.81                      802                 Other
# 1     skincare  SKU1  14.84                      736                Female
# 2     haircare  SKU2  11.32                        8                 Other
# 3     skincare  SKU3  61.16                       83                 Other
# 4     skincare  SKU4   4.81                      871                 Other
#
#    Stock levels  Order quantities Shipping carriers  Shipping costs  \
# 0            58                96         Carrier B            2.96
# 1            53                37         Carrier A            9.72
# 2             1                88         Carrier B            8.05
# 3            23                59         Carrier C            1.73
# 4             5                56         Carrier A            3.89
#
#   Supplier name Location  Lead time  Production volumes  \
# ...

# %%
df[truncate] = df[truncate].astype(str).apply(lambda x: x.str.replace('.', ','))
# Out:
# C:\Users\agoth\AppData\Local\Temp\ipykernel_16712\378841169.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[truncate] = df[truncate].astype(str).apply(lambda x: x.str.replace('.', ','))

# %%
df.head()
# Out:
#   Product type   SKU  Price  Number of products sold Customer demographics  \
# 0     haircare  SKU0  69,81                      802                 Other
# 1     skincare  SKU1  14,84                      736                Female
# 2     haircare  SKU2  11,32                        8                 Other
# 3     skincare  SKU3  61,16                       83                 Other
# 4     skincare  SKU4   4,81                      871                 Other
#
#    Stock levels  Order quantities Shipping carriers Shipping costs  \
# 0            58                96         Carrier B           2,96
# 1            53                37         Carrier A           9,72
# 2             1                88         Carrier B           8,05
# 3            23                59         Carrier C           1,73
# 4             5                56         Carrier A           3,89
#
#   Supplier name Location  Lead time  Production volumes  \
# ...

# %%
df.to_csv("supply2.csv", index=False)
